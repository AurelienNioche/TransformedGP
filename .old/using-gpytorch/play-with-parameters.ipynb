# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
# %config InlineBackend.figure_format = "retina";

# %%
def kernel(X1, X2, lengthscale=1.0, outputscale=1.0):
    sqdist = np.sum(X1**2, 1).reshape(-1, 1) + np.sum(X2**2, 1) - 2 * np.dot(X1, X2.T)
    return outputscale**2 * np.exp(-0.5 / lengthscale**2 * sqdist)

# %%
x = np.linspace(0, 1, 100)

# Mean and covariance of the prior
mu = x**(0.7)
cov = kernel(X, X, outputscale=0.01, lengthscale=100)

# Draw three samples from the prior
samples = np.random.multivariate_normal(mu, cov, 100)

fig, ax = plt.subplots()
ax.plot(x, samples.T, color='C1', alpha=0.5)
ax.plot(x, mu)
plt.show()
