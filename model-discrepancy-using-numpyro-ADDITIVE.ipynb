# %%
import os
import time

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import scipy

import jax
from jax import vmap
import jax.numpy as jnp
import jax.random as random

import numpyro
import numpyro.distributions as dist
from numpyro.infer import MCMC, NUTS, init_to_feasible, init_to_median, init_to_sample, \
    init_to_uniform, init_to_value

from pymc3.gp.util import plot_gp_dist
import pymc3 as pm
# import pymc3.sampling_jax

import pandas as pd
import numpy as np
from scipy.special import expit
import matplotlib.pyplot as plt
import cmdstanpy as stan
import seaborn as sns
import arviz as az

from tqdm import tqdm

# %%
# Don't sting my eyes
# %config InlineBackend.figure_format = 'retina'
sns.set()

# %%
# Default to double precision.
numpyro.enable_x64()

# %% [markdown]
# # Utility models

# %%
def u_pow(x, theta): return x**theta

# %%
def u_exp(x, theta): return 1 - np.exp(-theta*x)

# %%
def u_lin(x, theta=None): return x

# %% [markdown]
# # Generate choice data

# %%
def generate_data(u, seed=123, max_x=1, n=100, tau=3.333, theta=0.5):
    
    np.random.seed(seed)
    
    data = pd.DataFrame(np.random.uniform(0, 1, size=(n*10, 4)), columns=["p0", "x0", "p1", "x1"])
    for i in range(2):
        data[f"x{i}"] = data[f"x{i}"].values * max_x
    data = data[~((data.p0 >= data.p1) & (data.x0 >= data.x1))]
    data = data[~((data.p1 >= data.p0) & (data.x1 >= data.x0))]
    data = data.sample(n=n, replace=False)
    
    p0 = data.p0.values
    p1 = data.p1.values
    x0 = data.x0.values
    x1 = data.x1.values
    
    seu0 = p0 * u(x0, theta)
    seu1 = p1 * u(x1, theta)

    diff_eu = seu1 - seu0

    p_choice_1 = scipy.special.expit(tau*diff_eu)
    choices = np.zeros(n, dtype=int)
    choices[:] = p_choice_1 > np.random.random(size=n)
    data['choices'] = choices

    return data

# %%
data = generate_data(u=u_pow, n=1000, tau=3.333, theta=(0.5, ))
data
# Out:
#             p0        x0        p1        x1  choices
# 9002  0.696389  0.007647  0.617248  0.282997        1
# 7863  0.953285  0.292898  0.380948  0.552913        1
# 7455  0.060678  0.327938  0.685627  0.158464        1
# 3414  0.138550  0.276750  0.788651  0.125342        0
# 5796  0.116159  0.356232  0.732859  0.310642        0
# ...        ...       ...       ...       ...      ...
# 2857  0.928569  0.159319  0.006656  0.571188        0
# 5417  0.621396  0.103035  0.601608  0.871169        1
# 1854  0.218694  0.560962  0.389658  0.026879        1
# 8834  0.980679  0.073375  0.877985  0.777087        1
# 6976  0.329744  0.401403  0.030272  0.846973        1
#
# [1000 rows x 5 columns]

# %% [markdown]
# # Likelihood whole model given M, $\theta_M$

# %%
def softplus(x):
    return np.log(1 + np.exp(x))

def objective(param, data, u_m):
    
    param = softplus(param)  # All parameters all supposed to be R+
    
    tau = param[0]
    theta = param[1]
    
    p0 = data.p0.values
    p1 = data.p1.values
    x0 = data.x0.values
    x1 = data.x1.values
    y = data.choices.values 
    
    seu0 = p0 * u_m(x0, theta)
    seu1 = p1 * u_m(x1, theta)

    diff_eu = seu1 - seu0

    p_choice_1 = scipy.special.expit(tau*diff_eu) # p choose 1
    p_choice_y = p_choice_1**y * (1-p_choice_1)**(1-y)
    return - np.log(p_choice_y).sum()

# %%
def optimize(data, u_m=u_pow, x0=None):
    if x0 is None:
        x0 = (0.0, 0.0) # Assume two parameters
    opt = scipy.optimize.minimize(objective, x0=x0, args=(data, u_m))
    return softplus(opt.x)

# %%
optimize(data, u_m=u_pow)
# Out:
# array([3.28496491, 0.53506426])

# %% [markdown]
# # Measure discrepancy

# %% [markdown]
# ## Generate data

# %%
u_data = u_pow
theta_data = 0.5
tau_data = 3.333

# %%
data = generate_data(u=u_data, tau=tau_data, theta=theta_data, n=1000, seed=123)
np.random.seed(12345)
data = data.sample(n=100, replace=False)

# %%
optimize(data, u_m=u_pow)
# Out:
# array([3.4444072 , 0.39557323])

# %% [markdown]
# ## Using Pymc3

# %%
def run_inference_pymc3(data, u, theta, tau):
    
    p0 = data.p0.values
    p1 = data.p1.values
    x0 = data.x0.values
    x1 = data.x1.values
    y = data.choices.values

    x = np.hstack((x0, x1))
    p = np.hstack((p0, p1))

    x_order = np.argsort(x)
    x_sorted = x[x_order]
    p_sorted = p[x_order]
    undo_sorted = np.argsort(x_order)
    
    X = x_sorted.reshape(-1, 1)
    uX = u(x_sorted, theta)

    n = len(y)
    
    with pm.Model() as model:

        # ρ = pm.InverseGamma('ρ', 2, 2)
        # η = pm.HalfCauchy('η', 5)
        ρ = pm.TruncatedNormal('ρ', lower=0, mu=1., sigma=1.)
        η = pm.TruncatedNormal('η', lower=0, mu=1., sigma=1.)
        
        M = pm.gp.mean.Constant(uX)
        K = η**2 * pm.gp.cov.ExpQuad(1, ρ) 

        gp = pm.gp.Latent(mean_func=M, cov_func=K)
        f = gp.prior("f", X=X)

        est_eu_sorted =  p_sorted * f    
        est_eu = est_eu_sorted[undo_sorted]
        est_diff_eu = est_eu[n:] - est_eu[:n]

        choose_1 = pm.Bernoulli('obs', logit_p=tau*est_diff_eu, observed=y)

    with model:
        trace = pm.sample(1000, tune=1000, chains=1, 
                          return_inferencedata=True, target_accept=0.90)
    return X, trace

# %% [markdown]
# ### 'Good' prior

# %%
u_model = u_pow
theta_model = 0.5
tau_model = 3.333

X, trace = run_inference_pymc3(data=data, u=u_model, theta=theta_model, tau=tau_model)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [f_rotated_, η, ρ]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:13<00:00 Sampling chain 0, 6 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 1_000 draw iterations (1_000 + 1_000 draws total) took 133 seconds.
# There were 6 divergences after tuning. Increase `target_accept` or reparameterize.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
f_samples = np.array(trace.posterior["f"])
f_samples = f_samples.reshape(f_samples.shape[0]*f_samples.shape[1], -1)

# %%
fig, ax = plt.subplots()
plot_gp_dist(ax, f_samples, X)
ax.plot(X, u_model(X, theta=theta_model), ls="--");

# %%
az.plot_posterior(trace, var_names=['ρ', 'η']);

# %% [markdown]
# ### Linear prior

# %%
u_model = u_lin
theta_model = None
tau_model = 3.333

X, trace = run_inference_pymc3(data=data, u=u_model, theta=theta_model, tau=tau_model)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [f_rotated_, η, ρ]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 03:16<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 1_000 draw iterations (1_000 + 1_000 draws total) took 196 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
f_samples = np.array(trace.posterior["f"])
f_samples = f_samples.reshape(f_samples.shape[0]*f_samples.shape[1], -1)

# %%
fig, ax = plt.subplots()
plot_gp_dist(ax, f_samples, X)
ax.plot(X, u_model(X, theta=theta_model), ls="--");
ax.plot(X, u_data(X, theta=theta_data), ls=':', color="C2");

# %%
az.plot_posterior(trace, var_names=['ρ', 'η']);

# %% [markdown]
# ## Using numpyro

# %%
def kernel(X, Xs, length):
    deltaX = jnp.power((X[:, None] - Xs) / length, 2.0)
    return jnp.exp(-0.5 * deltaX)

# %%
def model(X, y, p, M, factor, undo_sorted, tau, jitter=1e-06):
    
    n_x = X.shape[0]
    n_y = y.shape[0]
    
    var = numpyro.sample('kernel_var', dist.TruncatedNormal(low=0, loc=1., scale=1.))
    length = numpyro.sample('kernel_length', dist.TruncatedNormal(low=0, loc=1., scale=1.))
    
    with numpyro.plate("-", n_x):
        eta = numpyro.sample('eta', dist.Normal(0, 1))
    
    K = factor * var**2 * kernel(X, X, length) + jitter * jnp.eye(n_x)
    L = jnp.linalg.cholesky(K)
    f = numpyro.deterministic("f", M + L.dot(eta))
    
    est_eu_sorted =  p * f    
    est_eu = est_eu_sorted[undo_sorted]

    est_diff_eu = est_eu[n_y:] - est_eu[:n_y]
    numpyro.sample("obs", dist.Bernoulli(logits=tau*est_diff_eu), obs=y)

# %%
def run_inference(data, u, theta, tau, use_ratio):
    
    p0 = data.p0.values
    p1 = data.p1.values
    x0 = data.x0.values
    x1 = data.x1.values
    y = data.choices.values

    x = np.hstack((x0, x1))
    p = np.hstack((p0, p1))

    x_order = np.argsort(x)
    x_sorted = x[x_order]
    p_sorted = p[x_order]
    undo_sorted = np.argsort(x_order)
    
    X = jnp.array(x_sorted)
    uX = jnp.array(u(X, theta))
    P = jnp.array(p_sorted)
    Y = jnp.array(y)

    M = uX
    
    if use_ratio:
        factor = uX * uX[:, None]
    else:
        factor = 1.

    rng_key = random.PRNGKey(0)

    nuts = MCMC(NUTS(model, target_accept_prob=0.9, max_tree_depth=10, 
                     init_strategy=init_to_uniform(radius=1),
                     adapt_mass_matrix=True,
                     dense_mass=False,),  # Default = 2
                num_samples=1000, num_warmup=1000)
    nuts.run(rng_key, X=X, y=Y, p=P, M=M, factor=factor, tau=tau, 
             undo_sorted=undo_sorted)
    return X, nuts

# %% [markdown]
# ### Using 'good' prior

# %%
u_data = u_pow
theta_data = 0.5
tau_data = 3.333

data = generate_data(u=u_data, tau=tau_data, theta=theta_data, n=1000, seed=123)
np.random.seed(12345)
data = data.sample(n=100, replace=False)

optimize(data, u_m=u_pow)
# Out:
# array([3.4444072 , 0.39557323])

# %%
u_model = u_pow
theta_model = 0.5
tau_model = 3.333

X, nuts = run_inference(
    data=data, 
    u=u_model, theta=theta_model, tau=tau_model,
    use_ratio=False)
# Out:
# sample: 100%|██████████| 2000/2000 [02:21<00:00, 14.17it/s, 31 steps of size 1.75e-01. acc. prob=0.93]

# %%
samples = nuts.get_samples()
f_samples = samples["f"]

# %%
fig, ax = plt.subplots()
plot_gp_dist(ax, f_samples, X)
ax.plot(X, u_model(X, theta_model), ls='--');

# %%
nuts.print_summary()
# Out:
#                      mean       std    median      5.0%     95.0%     n_eff     r_hat
#          eta[0]      0.20      0.59      0.17     -0.83      1.03   1073.45      1.00
#          eta[1]      0.01      0.94      0.01     -1.53      1.53   1846.71      1.00
#          eta[2]      0.04      0.88      0.02     -1.19      1.74   1374.79      1.00
#          eta[3]     -0.02      0.93     -0.00     -1.68      1.38   2607.45      1.00
#          eta[4]     -0.00      1.01      0.01     -1.76      1.51   2991.46      1.00
#          eta[5]      0.02      0.96      0.03     -1.78      1.42   2479.25      1.00
#          eta[6]      0.03      0.92      0.02     -1.53      1.44   1914.93      1.00
#          eta[7]      0.01      0.99     -0.01     -1.70      1.54   2441.50      1.00
#          eta[8]      0.03      1.06      0.02     -1.84      1.63   3335.80      1.00
#          eta[9]      0.05      1.02      0.06     -1.54      1.76   2016.01      1.00
#         eta[10]      0.01      1.04      0.01     -1.51      1.83   2363.21      1.00
#         eta[11]      0.01      1.01      0.02     -1.68      1.66   2365.90      1.00
#         eta[12]      0.02      1.00      0.00     -1.70      1.59   2570.12      1.00
#         eta[13]      0.01      1.02     -0.01     -1.70      1.57   2348.37      1.00
#         eta[14]      0.03      0.97      0.05     -1.37      1.79   1932.88      1.00
#         eta[15]     -0.04      1.06     -0.03     -1.76      1.63   2557.21      1.00
#         eta[16]     -0.01      0.98      0.01     -1.58      1.43   2175.05      1.00
#         eta[17]      0.01      1.01      0.01     -1.53      1.79   1789.54      1.00
#         eta[18]      0.01      0.99      0.02     -1.57      1.63   2506.11      1.00
#         eta[19]      0.01      0.94      0.00     -1.41      1.60   1829.06      1.00
#         eta[20]     -0.02      1.01     -0.03     -1.58      1.82   3256.69      1.00
#         eta[21]      0.01      0.95      0.02     -1.56      1.55   2264.50      1.00
#         eta[22]     -0.02      1.02     -0.02     -1.72      1.52   2946.14      1.00
#         eta[23]      0.03      1.07     -0.00     -1.52      1.91   2539.69      1.00
#         eta[24]     -0.04      0.99     -0.02     -1.75      1.49   2237.88      1.00
#         eta[25]      0.02      0.97      0.04     -1.57      1.52   2771.31      1.00
#         eta[26]     -0.03      0.99     -0.02     -1.56      1.63   1722.56      1.00
#         eta[27]      0.02      0.97      0.03     -1.59      1.65   2721.16      1.00
#         eta[28]     -0.01      0.98     -0.01     -1.53      1.75   2764.49      1.00
#         eta[29]     -0.04      1.04     -0.06     -1.72      1.54   2490.17      1.00
#        eta[184]      0.01      1.01      0.01     -1.94      1.42   2842.80      1.00
#        eta[185]     -0.01      1.07      0.02     -1.74      1.74   2744.46      1.00
#        eta[186]     -0.03      1.01     -0.01     -1.62      1.71   2526.06      1.00
#        eta[187]      0.02      0.99      0.01     -1.63      1.57   2198.05      1.00
#        eta[188]      0.01      0.98     -0.00     -1.49      1.67   3067.65      1.00
#        eta[189]      0.01      1.01      0.04     -1.58      1.64   2118.91      1.00
#        eta[190]     -0.04      1.07     -0.04     -1.98      1.63   2543.60      1.00
#        eta[191]     -0.04      1.00     -0.03     -1.50      1.77   2766.42      1.00
#        eta[192]     -0.01      1.02     -0.00     -1.84      1.49   2195.89      1.00
#        eta[193]      0.01      0.96      0.01     -1.52      1.57   2246.49      1.00
#        eta[194]     -0.02      0.92      0.00     -1.58      1.33   2635.03      1.00
#        eta[195]     -0.00      0.98     -0.02     -1.58      1.57   2273.06      1.00
#        eta[196]     -0.03      0.93     -0.03     -1.65      1.45   1882.79      1.00
#        eta[197]     -0.00      1.00     -0.00     -1.66      1.57   2460.06      1.00
#        eta[198]     -0.01      1.12     -0.02     -1.80      1.73   2280.35      1.00
#        eta[199]     -0.01      0.99     -0.02     -1.57      1.61   2203.79      1.00
#   kernel_length      1.48      0.78      1.41      0.21      2.76    613.29      1.00
#      kernel_var      0.48      0.49      0.32      0.00      1.15    498.07      1.00
#
# Number of divergences: 0

# %%
az_samples = az.from_numpyro(nuts)
az.plot_posterior(az_samples, var_names=['kernel_var', 'kernel_length']);
# Out:
# array([<AxesSubplot:title={'center':'kernel_var'}>,
#        <AxesSubplot:title={'center':'kernel_length'}>], dtype=object)

# %% [markdown]
# ### Using linear prior

# %%
u_model = u_lin
theta_model = None
tau_model = 3.333
X, nuts = run_inference(
    data=data, 
    u=u_model, theta=theta_model, tau=tau_model,
    use_ratio=False)
# Out:
# sample: 100%|██████████| 2000/2000 [02:45<00:00, 12.06it/s, 15 steps of size 2.06e-01. acc. prob=0.90]

# %%
f_samples = nuts.get_samples()["f"]

fig, ax = plt.subplots()
plot_gp_dist(ax, f_samples, X)
ax.plot(X, u_model(X, theta_model), ls='--');
ax.plot(X, u_data(X, theta_data), ls=':', color='C2');

# %%
nuts.print_summary()
# Out:
#                      mean       std    median      5.0%     95.0%     n_eff     r_hat
#          eta[0]      0.61      0.50      0.48     -0.05      1.42    271.52      1.00
#          eta[1]      0.01      0.95      0.02     -1.57      1.44   1230.33      1.00
#          eta[2]      0.13      0.82      0.13     -1.46      1.26    818.90      1.00
#          eta[3]     -0.02      0.95      0.01     -1.46      1.55   1329.57      1.00
#          eta[4]      0.05      1.03      0.03     -1.51      1.78   1181.14      1.00
#          eta[5]     -0.02      0.98      0.02     -1.79      1.45   1169.33      1.00
#          eta[6]      0.01      0.95      0.02     -1.70      1.35   1012.41      1.00
#          eta[7]     -0.02      1.03     -0.01     -1.70      1.66   1380.98      1.00
#          eta[8]     -0.01      1.04     -0.04     -1.70      1.72   1301.27      1.00
az.plot_posterior(az_samples, var_names=['kernel_var', 'kernel_length'])
# Out:
# array([<AxesSubplot:title={'center':'kernel_var'}>,
#        <AxesSubplot:title={'center':'kernel_length'}>], dtype=object)

# %% [markdown]
# # Sparse

# %%
def kernel(X, Xs, length):
    deltaX = jnp.power((X[:, None] - Xs) / length, 2.0)
    return jnp.exp(-0.5 * deltaX)

# %%
def sparse_model(X, y, p, init_order, u, theta, tau, T, jitter=1e-06):
    
    n = y.shape[0]
    
    var = numpyro.sample("kernel_var", dist.TruncatedNormal(low=0., loc=1., scale=1.))
    length = numpyro.sample("kernel_length", dist.TruncatedNormal(low=0., loc=1., scale=1.))
    
    with numpyro.plate("T", T):
        Xt = numpyro.sample("Xtrain", dist.Uniform(low=0, high=1))
        eta = numpyro.sample('eta', dist.Normal())
        
    Mt = jnp.asarray(u(Xt, theta))
    # K_factor = Mt[:, None] * Mt
    
    k_XX = var **2 * kernel(Xt, Xt, length) + jitter*jnp.eye(T)
    L = jnp.linalg.cholesky(k_XX)
    L_dot_eta = jnp.dot(L, eta)
    # f = Mt + L_dot_eta

    Mp = jnp.array(u(X, theta))
    # K_Xp_factor = Mt[:, None] * Mp
    
    K_Xp = var**2 * kernel(Xt, X, length)
    A = jax.scipy.linalg.solve_triangular(L, K_Xp, lower=True)
    v = jax.scipy.linalg.solve_triangular(L, L_dot_eta, lower=True)

    f_predict = numpyro.deterministic("f", Mp + A.T.dot(v))
    
    est_eu_sorted =  p * f_predict    
    est_eu = est_eu_sorted[init_order]
    est_diff_eu = est_eu[n:] - est_eu[:n]
    
    numpyro.sample("obs", dist.Bernoulli(logits=tau * est_diff_eu), obs=y)

# %%
def run_inference_sparse(data, u, theta, tau, T):
    p0 = data.p0.values
    p1 = data.p1.values
    x0 = data.x0.values
    x1 = data.x1.values
    y = data.choices.values

    x = np.hstack((x0, x1))
    p = np.hstack((p0, p1))

    x_order = np.argsort(x)
    x_sorted = x[x_order]
    p_sorted = p[x_order]
    undo_sorted = np.argsort(x_order)

    X = jnp.array(x_sorted)
    uX = jnp.array(u_model(X, theta_model))
    P = jnp.array(p_sorted)
    Y = jnp.array(y)
    
    # Set random seed for reproducibility.
    rng_key = random.PRNGKey(123)

    nuts = MCMC(NUTS(sparse_model, target_accept_prob=0.9, max_tree_depth=10, 
                     init_strategy=init_to_uniform(radius=1),
                     adapt_mass_matrix=True,
                     dense_mass=False),
                num_samples=1000, num_warmup=1000)
    nuts.run(rng_key, X=X, y=Y, p=P, init_order=undo_sorted, 
             u=u, theta=theta, tau=tau_model, T=T)
    return X, nuts

# %% [markdown]
# ## With 'good' prior

# %%
u_data = u_pow
theta_data = 0.5
tau_data = 3.333

# %%
data = generate_data(u=u_data, tau=tau_data, theta=theta_data, n=200, seed=123)

# %%
optimize(data, u_m=u_pow)
# Out:
# array([3.97130767, 0.48028541])

# %%
u_model = u_pow
theta_model = 0.5
tau_model = 3.333

# %%
X, nuts = run_inference_sparse(
    data=data, T=50,
    u=u_model, theta=theta_model, tau=tau_model)
# Out:
# sample: 100%|██████████| 2000/2000 [16:27<00:00,  2.03it/s, 1023 steps of size 6.06e-03. acc. prob=0.91]

# %%
f_samples = nuts.get_samples()["f"]

fig, ax = plt.subplots()
plot_gp_dist(ax, f_samples, X)
ax.plot(X, u_model(X, theta_model), ls='--')
ax.plot(X, u_data(X, theta_data), ls=':', color='C2');

# %%
az_samples = az.from_numpyro(nuts)
az.plot_posterior(az_samples, var_names=['kernel_var', 'kernel_length']);

# %% [markdown]
# ## With linear prior

# %%
u_data = u_pow
theta_data = 0.5
tau_data = 3.333

# %%
data = generate_data(u=u_data, tau=tau_data, theta=theta_data, n=200, seed=123)

# %%
optimize(data, u_m=u_pow)
# Out:
# array([3.97130767, 0.48028541])

# %%
u_model = u_lin
theta_model = None
tau_model = 3.333

# %%
X, nuts = run_inference_sparse(
    data=data, T=50,
    u=u_model, theta=theta_model, tau=tau_model)
# Out:
# sample: 100%|██████████| 2000/2000 [14:41<00:00,  2.27it/s, 1023 steps of size 6.06e-03. acc. prob=0.91]

# %%
f_samples = nuts.get_samples()["f"]

# %%
fig, ax = plt.subplots()
plot_gp_dist(ax, f_samples, X)
ax.plot(X, u_model(X, theta_model), ls='--')
ax.plot(X, u_data(X, theta_data), ls=':', color='C2');

# %%
az_samples = az.from_numpyro(nuts)
az.plot_posterior(az_samples, var_names=['kernel_var', 'kernel_length']);

# %% [markdown]
# # In case of need: Make predictions

# %%
def gp_predict(X, samples, u, theta, use_ratio, i, Xnew=None, jitter=1.0e-6):
    
    var=samples['kernel_var'][i]
    length=samples['kernel_length'][i]
    eta=samples['eta'][i] 
    
    uX = jnp.asarray(u(X, theta))
    
    N = X.shape[0]
    if use_ratio:
        factor = uX[:, None] * uX
    else:
        factor = 1
        
    k_XX = factor * var**2 * kernel(X, X, length) + jitter*jnp.eye(N)
    L = jnp.linalg.cholesky(k_XX)
    f = uX.flatten() + L.dot(eta)
    
    if Xnew is not None:
        M = Xnew.shape[0]
        
        up = jnp.asarray(u(Xnew, theta))
        if use_ratio:
            factor_Xp = uX[:, None] * up
        else:
            factor_Xp = 1
        
        K_Xp = factor_Xp * var**2 * kernel(X, Xnew, length)
        
        A = jax.scipy.linalg.solve_triangular(L, K_Xp, lower=True)
        v = jax.scipy.linalg.solve_triangular(L, f - uX.flatten(), lower=True)
        
        f_predict = up.flatten() + jnp.dot(A.T, v)
        
    else:
        f_predict = f
    
    return f_predict

# %%
Xtest = jnp.array(np.linspace(0, 1, 100))

n_samples = samples['kernel_var'].shape[0]
f_predict = np.zeros((n_samples, Xtest.shape[0]))

for i in tqdm(range(n_samples)):
    f_predict[i] = gp_predict(X=X, Xnew=Xtest, samples=samples, 
                              u=u_model, theta=theta_model, i=i)
# Out:
# 100%|██████████| 1000/1000 [00:19<00:00, 52.53it/s]

# %%
fig, ax = plt.subplots()
plot_gp_dist(ax, f_predict, Xtest)
ax.plot(Xtest, u_model(Xtest, theta_model), ls='--');
